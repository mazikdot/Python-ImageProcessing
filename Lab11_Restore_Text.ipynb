# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

# %%
src = cv.imread("./text.png")
gray_img = cv.cvtColor(src,cv.COLOR_BGR2GRAY)
_,bin_img = cv.threshold(gray_img,127,255,cv.THRESH_BINARY)
plt.rcParams["figure.figsize"] = [30, 18]
#plt.rcParams["figure.autolayout"] = True
plt.imshow(bin_img,cmap='gray'),plt.xticks([]),plt.yticks([])
plt.show()
#ใช้อะไรก็ได้ให้มันออกมาดีที่สุดเช่น openclose

# %%
rect3x3 = cv.getStructuringElement(cv.MORPH_RECT,(3,3))

# %%
dilated_img_rect3x3 =  cv.dilate(bin_img,rect3x3,iterations=2)
ALL_show_img = np.concatenate((dilated_img_rect3x3,bin_img),axis=1)
print("เปรียบเทียบภาพต้นฉบับ กับภาพที่ได้จากการ dialte : ")
plt.imshow(ALL_show_img,cmap='gray')
# Out:
# เปรียบเทียบภาพต้นฉบับ กับภาพที่ได้จากการ dialte :
