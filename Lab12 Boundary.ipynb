# %%
#Lab12 วัตถุควรเป็นสีขาว
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

# %%
src = cv.imread("StarWhite.png")
gray_img = cv.cvtColor(src,cv.COLOR_BGR2GRAY)
_,bin_img = cv.threshold(gray_img,127,255,cv.THRESH_BINARY)
plt.rcParams["figure.figsize"] = [15, 15]
plt.imshow(bin_img,cmap='gray'),plt.xticks([]),plt.yticks([])
plt.show()

# %%
#เอาภาพต้นฉบับ มาลบกับภาพที่ถูกกัดแล้ว
rect3x3 = cv.getStructuringElement(cv.MORPH_RECT,(3,3))
cross3x3 = cv.getStructuringElement(cv.MORPH_CROSS,(3,3))
ellipse3x3 = cv.getStructuringElement(cv.MORPH_ELLIPSE,(3,3))
rect5x5 = cv.getStructuringElement(cv.MORPH_RECT,(5,5))
cross5x5 = cv.getStructuringElement(cv.MORPH_CROSS,(5,5))
ellipse5x5 = cv.getStructuringElement(cv.MORPH_ELLIPSE,(5,5))
elip30x30= cv.getStructuringElement(cv.MORPH_ELLIPSE,(30,30))

# %%
errode_img = cv.erode(gray_img,elip30x30)
#อยากได้ขอบหนา kernel ต้องมาก
boundary_img =gray_img - errode_img
plt.rcParams["figure.figsize"] = [25, 50]
# 1 แถว สาม คอลัม 1 3 1    => 1 ตัวสุดท้ายคือภาพที่โชว์ลำดับแรก
plt.subplot(131),plt.imshow(boundary_img,cmap='gray'),plt.title('Boundary Image')
plt.xticks([]), plt.yticks([])
plt.subplot(132),plt.imshow(gray_img,cmap='gray'),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(133),plt.imshow(errode_img,cmap='gray'),plt.title('Erode')
plt.xticks([]), plt.yticks([])
plt.show()
#ต้องเช็คคำตอบอีกครั้งในภาพที่ชื่อว่า Lab12
